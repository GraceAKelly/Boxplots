# %% [markdown]
# # An Investigation into the use and function of box plots

# %% [markdown]
# A box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram. Outliers may be plotted as individual points. (https://en.wikipedia.org/wiki/Box_plot)
#
# To draw a box plot, the following information is needed:
#
# minimum value
# lower quartile
# median
# upper quartile
# maximum value
#
# (https://www.bbc.com/bitesize/guides/zc7sb82/revision/7)
#
# ![Boxplot](https://bam.files.bbci.co.uk/bam/live/content/zpym6fr/small)
#
# Box plots are useful for identifying outliers and for comparing distributions.(http://onlinestatbook.com/2/graphing_distributions/boxplots.html)

# %%
import numpy as np  # import numnerical python with shorthand  
import matplotlib.pyplot as plt  # shorthand import for matplotlib library
import seaborn as sns # import seaborn for advanced graphics
import pandas as pd # import pandas for to take data from table in a csv file

# %%
df = pd.read_csv("BlackFridayData.csv") # (https://www.kaggle.com/mehdidag/black-friday/version/1)

# %%
df
# Out:
#       User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0     1000001  P00069042      F   0-17          10             A
# 1     1000001  P00248942      F   0-17          10             A
# 2     1000001  P00087842      F   0-17          10             A
# 3     1000001  P00085442      F   0-17          10             A
# 4     1000002  P00285442      M    55+          16             C
# 5     1000003  P00193542      M  26-35          15             A
# 6     1000004  P00184942      M  46-50           7             B
# 7     1000004  P00346142      M  46-50           7             B
# 8     1000004   P0097242      M  46-50           7             B
# 9     1000005  P00274942      M  26-35          20             A
# 10    1000005  P00251242      M  26-35          20             A
# 11    1000005  P00014542      M  26-35          20             A
# 12    1000005  P00031342      M  26-35          20             A
# ...

# %%
df.loc[:,'Age']
# Out:
# 0        0-17
# 1        0-17
# 2        0-17
# 3        0-17
# 4         55+
# 5       26-35
# 6       46-50
# 7       46-50
# 8       46-50
# 9       26-35
# 10      26-35
# 11      26-35
# 12      26-35
# 13      26-35
# 14      51-55
# 15      51-55
# 16      51-55
# 17      51-55
# 18      36-45
# 19      26-35
# 20      26-35
# 21      26-35
# 22      26-35
# 23      26-35
# 24      26-35
# 25      26-35
# 26      26-35
# 27      26-35
# 28      26-35
# 29      36-45
#         ...
# 4969    26-35
# 4970    26-35
# 4971    26-35
# 4972    26-35
# 4973    26-35
# 4974    26-35
# 4975    26-35
# 4976    51-55
# 4977    51-55
# 4978    26-35
# 4979    26-35
# 4980    26-35
# 4981    26-35
# 4982    26-35
# 4983    18-25
# 4984    18-25
# 4985    18-25
# 4986    18-25
# 4987    18-25
# 4988    46-50
# 4989    46-50
# 4990    46-50
# 4991    46-50
# 4992    46-50
# 4993    46-50
# 4994    46-50
# 4995    18-25
# 4996    18-25
# 4997    18-25
# 4998    18-25
# ...

# %%
df.boxplot(column='Purchase', by='Gender')
# Out:
# C:\Users\Neil\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
plt.show()

# %%
loc uses labels
iloc uses position
# Out:
#   File "<ipython-input-15-db4ceb06aea0>", line 1
#     loc uses labels
#            ^
# SyntaxError: invalid syntax
